# %% [markdown]
# # Project title: Analysis of Heart Disease Indicators
#
# ### Purpose of the project:
# To understand behavioral risk factors for various diseases (e.g., heart, kidney, etc.)

# %%
import numpy as np
import pandas as pd 
import os

# %%
heart_disease= pd.read_csv("heart_2020_cleaned.csv")
heart_disease.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
heart_disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
heart_disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
heart_disease.isnull().any()
# Out:
# HeartDisease        False
# BMI                 False
# Smoking             False
# AlcoholDrinking     False
# Stroke              False
# PhysicalHealth      False
# MentalHealth        False
# DiffWalking         False
# Sex                 False
# AgeCategory         False
# Race                False
# Diabetic            False
# PhysicalActivity    False
# GenHealth           False
# SleepTime           False
# Asthma              False
# KidneyDisease       False
# SkinCancer          False
# dtype: bool

# %% [markdown]
# ## In this project we are going to use the Personal Key Indicators of Heart Disease dataset to answer the following questions:
# #### Elliott’s Questions:
# Do people with a higher BMI have a higher increase chance of heart disease?
# Answer: (2 sample t-test to determine if the mean value between the two sample groups differ)
# 2. Instead of heart disease what about kidney disease?  Run same analysis.
# Optional Question:  Kidney disease and Heart disease, how are they affected by the BMI 2-way anova.

# %%
#one-hot enconding the categorical data into numerical
column_yes_no = ["HeartDisease", "Smoking", "AlcoholDrinking", "Stroke", "DiffWalking", "Diabetic", "PhysicalActivity", "Asthma", "KidneyDisease", "SkinCancer"]

heart_disease[column_yes_no] = heart_disease[column_yes_no].apply(lambda x: x.map({'Yes':1,'No':0}))

# %%
heart_disease
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0             3.0
# 1                  0  20.34        0                0       1             0.0
# 2                  0  26.58        1                0       0            20.0
# 3                  0  24.21        0                0       0             0.0
# 4                  0  23.71        0                0       0            28.0
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0             7.0
# 319791             0  29.84        1                0       0             0.0
# 319792             0  24.24        0                0       0             0.0
# 319793             0  32.81        0                0       0             0.0
# 319794             0  46.56        0                0       0             0.0
#
# ...

# %%
#Changing Male Sex to 1 and Female Sex to 0

column_1_0=["Sex"]
heart_disease[column_1_0] = heart_disease[column_1_0].apply(lambda x: x.map({'Male':1,'Female':0}))
heart_disease
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0             3.0
# 1                  0  20.34        0                0       1             0.0
# 2                  0  26.58        1                0       0            20.0
# 3                  0  24.21        0                0       0             0.0
# 4                  0  23.71        0                0       0            28.0
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0             7.0
# 319791             0  29.84        1                0       0             0.0
# 319792             0  24.24        0                0       0             0.0
# 319793             0  32.81        0                0       0             0.0
# 319794             0  46.56        0                0       0             0.0
#
# ...

# %%
len(heart_disease.columns)
# Out:
# 18

# %%
heart_disease.Diabetic.value_counts()
# Out:
# 0.0    269653
# 1.0     40802
# Name: Diabetic, dtype: int64

# %%
one_hot = pd.get_dummies(heart_disease[['AgeCategory','Race','GenHealth']])

# %%
Heart_Disease_concat=pd.concat([heart_disease, one_hot], axis=1)
Heart_Disease_concat

# %%
Heart_Disease_concat
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0             3.0
# 1                  0  20.34        0                0       1             0.0
# 2                  0  26.58        1                0       0            20.0
# 3                  0  24.21        0                0       0             0.0
# 4                  0  23.71        0                0       0            28.0
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0             7.0
# 319791             0  29.84        1                0       0             0.0
# 319792             0  24.24        0                0       0             0.0
# 319793             0  32.81        0                0       0             0.0
# 319794             0  46.56        0                0       0             0.0
#
# ...
